# %%
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np

# %%
raw_results = np.load("result_non_anneal.npz")
print(list(raw_results.keys()))
# Out:
# ['logbetas', 'result_K', 'result_D', 'recon_loss', 'kl_loss', 'individule_kl_loss']

# %%
locals().update(raw_results)

# %%
plt.figure(figsize=(10,10))
plt.plot(np.power(10,logbetas),result_D)
plt.semilogx()
plt.ylim([0,40])
plt.ylabel("heat capacity D" ,fontsize=40)
plt.xlabel(r"$\beta$" ,fontsize=40)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig(os.path.join("Plots","heat_capacity_D.pdf"), dpi=200)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(np.power(10,logbetas),result_K)
plt.semilogx()
plt.ylim([0,10])
plt.ylabel("heat capacity K",fontsize=40)
plt.xlabel(r"$\beta$" ,fontsize=40)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig(os.path.join("Plots","heat_capacity_K.pdf"), dpi=200)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(np.power(10,logbetas),result_K, label = "$C_{KL}$")
plt.plot(np.power(10,logbetas),result_D, label = "$C_{S}$")
plt.semilogx()
plt.ylim([0,40])
plt.ylabel("heat capacity",fontsize=40)
plt.xlabel(r"$\beta$" ,fontsize=40)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(fontsize=30)
plt.savefig(os.path.join("Plots","heat_capacity.pdf"), dpi=200)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(np.power(10,logbetas),recon_loss)
plt.semilogx()
plt.ylabel("reconstruction loss",fontsize=40)
plt.xlabel(r"$\beta$",fontsize=40)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig(os.path.join("Plots","recon_loss.pdf"), dpi=200)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(np.power(10,logbetas),kl_loss)
plt.semilogx()
plt.ylabel("KL divergence",fontsize=40)
plt.xlabel(r"$\beta$",fontsize=40)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig(os.path.join("Plots","kl_loss.pdf"), dpi=200)
plt.show()

# %%
plt.figure(figsize=(10,10))
for kl_loss in individule_kl_loss.T:
    plt.plot(np.power(10,logbetas), kl_loss)
plt.ylabel("KL divergence",fontsize=40)
plt.xlabel(r"$\beta$",fontsize=40)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.semilogx()
plt.savefig(os.path.join("Plots","individual_kl_loss.pdf"), dpi=200)
plt.show()
