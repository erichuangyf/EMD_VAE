# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plot_utils import *
import numpy as np
import os
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15, 12)

# %%
plot_root_dir = r"/global/home/users/yifengh3/VAE/EMD_VAE/recon_kinematic_plot/B_signal_vector_plots"

# %%
try: 
    os.mkdir(plot_root_dir) 
except:
    pass

# %%
recon_data = r"/global/home/users/yifengh3/VAE/vec_data/vec_model_no_anneal/reconstructed_B_signal_vector.npz"

# %%
raw_data = np.load(recon_data)

# %%
list(raw_data.keys())
# Out:
# ['data', 'recon', 'beta']

# %%
original_data = raw_data["data"]
recon_data = raw_data["recon"]
log_betas = raw_data["beta"]

# %%
beta_idx = np.logical_and(log_betas<-1, log_betas>-4)
new_betas = log_betas[beta_idx]

# %%
# plt.rcParams["figure.figsize"] = (15, 12)
compare_recons(original_data , recon_data[beta_idx], new_betas, plot_root_dir, pbar = True, njets=3, split=5)
# Out:
# 100%|████████████████████████████████| 163600/163600 [00:06<00:00, 26047.42it/s]
# 100%|████████████████████████████████| 163600/163600 [00:06<00:00, 26300.22it/s]
# 100%|████████████████████████████████| 163600/163600 [00:06<00:00, 26543.11it/s]
# 100%|████████████████████████████████| 163600/163600 [00:06<00:00, 26459.74it/s]
# 100%|████████████████████████████████| 163600/163600 [00:06<00:00, 27085.89it/s]
# 100%|████████████████████████████████| 163600/163600 [00:06<00:00, 26096.82it/s]
# 100%|████████████████████████████████| 163600/163600 [00:03<00:00, 45090.80it/s]
# 100%|████████████████████████████████| 163600/163600 [00:04<00:00, 40097.44it/s]
# 100%|████████████████████████████████| 163600/163600 [00:04<00:00, 39898.20it/s]
# 100%|████████████████████████████████| 163600/163600 [00:03<00:00, 43788.10it/s]
# 100%|████████████████████████████████| 163600/163600 [00:03<00:00, 42539.30it/s]
# 100%|████████████████████████████████| 163600/163600 [00:03<00:00, 44981.58it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:27<00:00, 5902.70it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5334.68it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5287.90it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:31<00:00, 5273.69it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5293.55it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:31<00:00, 5274.86it/s]
# /global/home/users/yifengh3/anaconda3/envs/tf2_new/lib/python3.8/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /global/home/users/yifengh3/VAE/EMD_VAE/recon_kinematic_plot/plot_utils.py:180: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale("log")

# %%
# plot_recon_jet(recon_data, log_betas, plot_root_dir)

# %%
# # get the original kinematic plot
# save_dir = os.path.join(plot_root_dir,"original_plot")
# try: 
#     os.mkdir(save_dir) 
# except:
#     pass
# plot_everything([original_data,], ["original_data",], save_plot_dir = save_dir, show_plot=False, pbar=False)
