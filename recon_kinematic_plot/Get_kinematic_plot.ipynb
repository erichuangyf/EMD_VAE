# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plot_utils import *
import numpy as np
import os
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15, 12)

# %%
plot_root_dir = r"/global/home/users/yifengh3/VAE/EMD_VAE/recon_kinematic_plot/B_signal_vector_plots"

# %%
try: 
    os.mkdir(plot_root_dir) 
except:
    pass

# %%
recon_data = r"/global/home/users/yifengh3/VAE/vec_data/vec_model_no_anneal/reconstructed_hv_vector.npz"

# %%
raw_data = np.load(recon_data)

# %%
raw_data["data"].shape
# Out:
# (33108, 50, 3)

# %%
list(raw_data.keys())
# Out:
# ['data', 'recon', 'beta']

# %%
original_data = raw_data["data"]
recon_data = raw_data["recon"]
log_betas = raw_data["beta"]

# %%
beta_idx = np.logical_and(log_betas<-1, log_betas>-4)
new_betas = log_betas[beta_idx]

# %%
# plt.rcParams["figure.figsize"] = (15, 12)
compare_recons(original_data , recon_data[beta_idx], new_betas, plot_root_dir, pbar = True, njets=3, split=5)
# Out:
# 100%|██████████████████████████████████| 33108/33108 [00:01<00:00, 27184.77it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:01<00:00, 27119.57it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:01<00:00, 29715.14it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:01<00:00, 28984.88it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:01<00:00, 27012.21it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:01<00:00, 27059.95it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:00<00:00, 46797.31it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:00<00:00, 42524.57it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:00<00:00, 41788.33it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:00<00:00, 39580.51it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:00<00:00, 42195.59it/s]
# 100%|██████████████████████████████████| 33108/33108 [00:00<00:00, 41397.11it/s]
# 100%|███████████████████████████████████| 33108/33108 [00:05<00:00, 5872.42it/s]
# 100%|███████████████████████████████████| 33108/33108 [00:06<00:00, 5301.18it/s]
# 100%|███████████████████████████████████| 33108/33108 [00:06<00:00, 5332.62it/s]
# 100%|███████████████████████████████████| 33108/33108 [00:06<00:00, 5323.99it/s]
# 100%|███████████████████████████████████| 33108/33108 [00:06<00:00, 5326.98it/s]
# 100%|███████████████████████████████████| 33108/33108 [00:06<00:00, 5293.01it/s]

# %%
# plot_recon_jet(recon_data, log_betas, plot_root_dir)

# %%
# # get the original kinematic plot
# save_dir = os.path.join(plot_root_dir,"original_plot")
# try: 
#     os.mkdir(save_dir) 
# except:
#     pass
# plot_everything([original_data,], ["original_data",], save_plot_dir = save_dir, show_plot=False, pbar=False)
