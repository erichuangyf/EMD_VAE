# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plot_utils import *
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
plot_root_dir = r"/global/home/users/yifengh3/VAE/vec_data/recon_plots/hv_vector_etadecay"

# %%
try: 
    os.mkdir(plot_root_dir) 
except:
    pass

# %%
recon_data = r"/global/home/users/yifengh3/VAE/vec_data/recon_data/reconstructed_hv_vector_etadecay.npz"

# %%
raw_data = np.load(recon_data)

# %%
list(raw_data.keys())
# Out:
# ['data', 'recon', 'beta']

# %%
original_data = raw_data["data"]
recon_data = raw_data["recon"]
log_betas = raw_data["beta"]

# %%
# # get the original kinematic plot
# save_dir = os.path.join(plot_root_dir,"original_plot")
# try: 
#     os.mkdir(save_dir) 
# except:
#     pass
# plot_everything([original_data,], ["original_data",], save_plot_dir = save_dir, show_plot=False, pbar=False)

# %%
beta_idx = np.logical_and(log_betas<-1, log_betas>-4)
new_betas = log_betas[beta_idx]

# %%
njets, pTleadjets, mleadjets = jet_clustering(original_data, 10, pbar = True, num_of_jets = 3)
# Out:
# 100%|███████████████████████████████████| 33312/33312 [00:05<00:00, 5854.43it/s]

# %%
compare_recons(original_data , recon_data[beta_idx], new_betas, plot_root_dir, pbar = True, njets=3, split=5, dpi=200)
# Out:
# 100%|██████████████████████████████████| 33312/33312 [00:01<00:00, 25918.04it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:01<00:00, 25058.26it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:01<00:00, 25726.11it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:01<00:00, 25902.29it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:01<00:00, 25892.66it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:01<00:00, 26092.14it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:00<00:00, 44889.80it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:00<00:00, 40301.83it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:00<00:00, 40104.16it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:00<00:00, 39322.58it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:00<00:00, 41068.45it/s]
# 100%|██████████████████████████████████| 33312/33312 [00:00<00:00, 39243.52it/s]
# 100%|███████████████████████████████████| 33312/33312 [00:05<00:00, 5898.09it/s]
# 100%|███████████████████████████████████| 33312/33312 [00:06<00:00, 5260.77it/s]
# 100%|███████████████████████████████████| 33312/33312 [00:06<00:00, 5149.33it/s]
# 100%|███████████████████████████████████| 33312/33312 [00:06<00:00, 5231.80it/s]
# 100%|███████████████████████████████████| 33312/33312 [00:06<00:00, 5220.17it/s]
# 100%|███████████████████████████████████| 33312/33312 [00:06<00:00, 5226.27it/s]

# %%
# plot_recon_jet(recon_data, log_betas, plot_root_dir)
