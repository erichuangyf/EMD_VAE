# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plot_utils import *
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
plot_root_dir = r"/global/home/users/yifengh3/VAE/vec_data/recon_plots/hv_pfn"

# %%
try: 
    os.mkdir(plot_root_dir) 
except:
    pass

# %%
recon_data = r"/global/home/users/yifengh3/VAE/vec_data/recon_data/pfn_hv_signal.npz"

# %%
raw_data = np.load(recon_data)

# %%
list(raw_data.keys())
# Out:
# ['data', 'recon', 'beta']

# %%
original_data = raw_data["data"]
recon_data = raw_data["recon"]
log_betas = raw_data["beta"]

# %%
# # get the original kinematic plot
# save_dir = os.path.join(plot_root_dir,"original_plot")
# try: 
#     os.mkdir(save_dir) 
# except:
#     pass
# plot_everything([original_data,], ["original_data",], save_plot_dir = save_dir, show_plot=False, pbar=False)

# %%
# beta_idx = np.logical_and(log_betas<-1, log_betas>-4)
# new_betas = log_betas[beta_idx]

# %%
# njets, pTleadjets, mleadjets = jet_clustering(original_data, 10, pbar = True, num_of_jets = 3)

# %%
compare_recons(original_data , recon_data, log_betas, plot_root_dir, pbar = True, njets=3, split=5, dpi=200)
# Out:
# 100%|████████████████████████████████| 155841/155841 [00:05<00:00, 27119.41it/s]
# 100%|████████████████████████████████| 155841/155841 [00:05<00:00, 28108.55it/s]
# 100%|████████████████████████████████| 155841/155841 [00:05<00:00, 27555.14it/s]
# 100%|████████████████████████████████| 155841/155841 [00:06<00:00, 25492.86it/s]
# 100%|████████████████████████████████| 155841/155841 [00:06<00:00, 25744.47it/s]
# 100%|████████████████████████████████| 155841/155841 [00:05<00:00, 26397.48it/s]
# 100%|████████████████████████████████| 155841/155841 [00:03<00:00, 45309.68it/s]
# 100%|████████████████████████████████| 155841/155841 [00:03<00:00, 39952.18it/s]
# 100%|████████████████████████████████| 155841/155841 [00:03<00:00, 42103.38it/s]
# 100%|████████████████████████████████| 155841/155841 [00:03<00:00, 39614.07it/s]
# 100%|████████████████████████████████| 155841/155841 [00:04<00:00, 38754.42it/s]
# 100%|████████████████████████████████| 155841/155841 [00:03<00:00, 42727.57it/s]
# 100%|█████████████████████████████████| 155841/155841 [00:26<00:00, 5864.20it/s]
# 100%|█████████████████████████████████| 155841/155841 [00:28<00:00, 5437.44it/s]
# 100%|█████████████████████████████████| 155841/155841 [00:28<00:00, 5487.99it/s]
# 100%|█████████████████████████████████| 155841/155841 [00:29<00:00, 5345.80it/s]
# 100%|█████████████████████████████████| 155841/155841 [00:29<00:00, 5360.37it/s]
# 100%|█████████████████████████████████| 155841/155841 [00:29<00:00, 5299.90it/s]
# /global/home/users/yifengh3/anaconda3/envs/tf2_new/lib/python3.8/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
# plot_recon_jet(recon_data, log_betas, plot_root_dir)
