# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plot_utils import *
import numpy as np
import os
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15, 12)

# %%
plot_root_dir = r"/global/home/users/yifengh3/VAE/vec_data/recon_plots/B_signal_for_pfn"

# %%
try: 
    os.mkdir(plot_root_dir) 
except:
    pass

# %%
recon_data = r"/global/home/users/yifengh3/VAE/vec_data/recon_data/pfn_bsignal.npz"

# %%
raw_data = np.load(recon_data)

# %%
raw_data["data"].shape
# Out:
# (163600, 50, 3)

# %%
list(raw_data.keys())
# Out:
# ['data', 'recon', 'beta']

# %%
original_data = raw_data["data"]
recon_data = raw_data["recon"]
log_betas = raw_data["beta"]

# %%
beta_idx = np.logical_and(log_betas<-1, log_betas>-4)
new_betas = log_betas[beta_idx]

# %%
njets, pTleadjets, mleadjets = jet_clustering(original_data, 10, num_of_jets=3)
# Out:
# 100%|█████████████████████████████████| 163600/163600 [00:26<00:00, 6084.64it/s]

# %%
plt.figure(figsize=(8,5))
plt.hist(mleadjets[1], density=True)
plt.show()

# %%
# plt.rcParams["figure.figsize"] = (15, 12)
compare_recons(original_data , recon_data[beta_idx], new_betas, plot_root_dir, pbar = True, njets=3, split=5, mjet_xlim=None)
# Out:
# 100%|████████████████████████████████| 163600/163600 [00:05<00:00, 28294.04it/s]
# 100%|████████████████████████████████| 163600/163600 [00:05<00:00, 29234.32it/s]
# 100%|████████████████████████████████| 163600/163600 [00:05<00:00, 28275.63it/s]
# 100%|████████████████████████████████| 163600/163600 [00:06<00:00, 26124.65it/s]
# 100%|████████████████████████████████| 163600/163600 [00:05<00:00, 28430.24it/s]
# 100%|████████████████████████████████| 163600/163600 [00:05<00:00, 28104.30it/s]
# 100%|████████████████████████████████| 163600/163600 [00:03<00:00, 47124.67it/s]
# 100%|████████████████████████████████| 163600/163600 [00:03<00:00, 41715.67it/s]
# 100%|████████████████████████████████| 163600/163600 [00:03<00:00, 40988.83it/s]
# 100%|████████████████████████████████| 163600/163600 [00:04<00:00, 40383.82it/s]
# 100%|████████████████████████████████| 163600/163600 [00:04<00:00, 40546.27it/s]
# 100%|████████████████████████████████| 163600/163600 [00:04<00:00, 40658.81it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:27<00:00, 6046.19it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5349.42it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5348.61it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5313.83it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5340.73it/s]
# 100%|█████████████████████████████████| 163600/163600 [00:30<00:00, 5301.98it/s]
# /global/home/users/yifengh3/VAE/EMD_VAE/recon_kinematic_plot/plot_utils.py:202: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale("log")

# %%
# plot_recon_jet(recon_data, log_betas, plot_root_dir)

# %%
# # get the original kinematic plot
# save_dir = os.path.join(plot_root_dir,"original_plot")
# try: 
#     os.mkdir(save_dir) 
# except:
#     pass
# plot_everything([original_data,], ["original_data",], save_plot_dir = save_dir, show_plot=False, pbar=False)
